# %%
# 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
"""

autorag evaluate --qa_data_path ./data/qa_mini.parquet --corpus_data_path ./data/corpus.parquet \
--config ./config.yaml --project_dir ./project
"""
# Out:
# '\n\nautorag evaluate --qa_data_path ./data/qa_mini --corpus_data_path ./data/corpus.parquet --config ./config.yaml --project_dir ./project\n'

# %%
import pandas as pd

# %%
df = pd.read_parquet('../data/qa_train.parquet')
corpus_df = pd.read_parquet('../data/corpus.parquet')

# %%
mini_df = df.iloc[:15, :]
mini_df.to_parquet('../data/qa_mini.parquet')

# %%
mini_df = df.sample(50)

# %%
mini_df.to_parquet('../data/qa_mini.parquet')

# %%
corpus_df[corpus_df['doc_id'] == '5b957791-3c7b-4f29-a410-8d005a538855]']
# Out:
# Empty DataFrame
# Columns: [contents, doc_id, metadata]
# Index: []

# %%
corpus_df.sample(50)
# Out:
#                                                contents  \
# 1865  bipartisan commission to investigate condition...
# 1379  he will help them find, so they could get back...
# 804   He was an independent candidate in the 2004 Af...
# 1756  Cantonese seafood soup Description The soup is...
# 1428  addresses, and also blocked new Facebook accou...
# 1554  include portion size, serving aids, food varie...
# 167   labs in the United States, Brazil, Venezuela, ...
# 1751  them as their romantic partner will be seen as...
# 534   Uniform Reciprocal Enforcement of Support Act ...
# 1473  calling the album "catchy in a really weird wa...
# 1167  Original fight song of the 442nd Battalion Haw...
# 1064  Bible translations into Romansh Bible translat...
# 945   was depicted early in the film The Right Stuff...
# 56    'financial weapons of mass destruction.' A pot...
# 124   that they don't tend to leak. This is particul...
# 1601  truthful tweets. More so, it is humans who are...
# ...

# %%
mini = pd.read_parquet('../data/qa_mini.parquet')

# %%
mini
# Out:
#         qid                                              query  \
# 443   jpsxm                ; Bohr vs Einstein puzzle solution.
# 178  2citow  How did the Romans express numbers in speech a...
# 119  1jok76               Why do some people get brain freeze?
# 131  1yz7y3  Why do people bother keeping savings in banks/...
# 122  1zgwa3                    Computer/TV Screen Size Pricing
# 203  1m3lq8                    how can i press my stomach out?
# 558  6fo0pq  Why do we, and all other animals, breath and u...
# 128  5jhpn6  What happens to Lactose when ingested by Lacto...
# 285  1lk863                                     Animal cloning
# 343  2hh6rz  How are branded drinks mass produced? (Gatorad...
# 591  1wox4m  Why do I get a feeling someone's watching me e...
# 431  6k5n43  ELI5:Why is it that a small animal will run up...
# 259  5xxcgy  Why haven't people as a whole adapted to the c...
# 396  512m77  Why do lights and stars sometimes appear to ha...
# ...

# %%
df
# Out:
#         qid                                              query  \
# 0    1oy5tc  in football whats the point of wasting the fir...
# 1    2lojul  Why are different tiers (regular < mid < premi...
# 2    8v5e3s                               Stars and Visibility
# 3    1v3wij  How do we know all the money the government is...
# 4    2jlp6f  What are good and bad sides of manual and auto...
# ..      ...                                                ...
# 595  6jh1hs  Why is a mouse more accurate than a joystick o...
# 596  57ebex  When was the last time in human history it wou...
# 597  2otv6y  Why do some drinks seem to pass right through ...
# 598  2bhw0n  How does a disease make a comeback like Ebola ...
# 599  1u6c55       How do they clean up the lead at gun ranges?
#
#                                          generation_gt  \
# 0    [Keep the defense honest, get a feel for the p...
# 1    [As someone who uses quality Premium, I wish t...
# ...
